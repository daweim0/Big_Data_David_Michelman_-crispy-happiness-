# %% [markdown]
# # Lab 3: Analasys of Movies With the Bechdel Test and
# By David Michelman, 3-7-2016

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Bechdel test first debuted in 1985 in  Alison Bechdel's comic strip "Dykes to Watch Out For," and is, in essence, a way to quantitatively tell if movies have female characters. In order for a movie to pass, it must have
#
# 1: at least two female characters who
#
# 2: must talk to each other
#
# 3: about something other than men.
# While seemingly simple, a large percentage of movies of all budgets fail this test.
#
#
# In this study, we will explore correlation between a movies return, or its revenue divided by its budget, and its reason for passing or failing the Bechdel test. We will also examine if dispute over a movie's test result has any effect on its return.

# %% [markdown]
# ## Code
# The following section reads the input file and contains function declerations used in later analasys sections.

# %%
# %matplotlib notebook

import numpy as np
import csv
import copy
import math
import scipy.stats as stats
import matplotlib.pyplot as plt

raw_file = open('movies.csv')

reader = csv.reader(raw_file)

intermediate_data_list_because_csv_wont_tell_us_how_long_a_file_is = list()

first_line = True

for line in reader:
    if first_line:
        headers = line
        first_line = False
    else:
        intermediate_data_list_because_csv_wont_tell_us_how_long_a_file_is.append(line)

data = np.zeros((len(headers), len(intermediate_data_list_because_csv_wont_tell_us_how_long_a_file_is)),
                dtype=object)

# data array is structured as follows: data[data feild being accessed, n_movie]

for line_n in range(len(intermediate_data_list_because_csv_wont_tell_us_how_long_a_file_is)):
    line_components = intermediate_data_list_because_csv_wont_tell_us_how_long_a_file_is[line_n]
    for i in range(len(line_components)):
        line_data = str(line_components[i])
        data[i][line_n] = line_data

def bar_graph_divided(data_array, index, title, y_label, categories=None):
    """
    Shows a plot of the passed data, plt.show() must be called after all calls of scatter_plot()
    :param index: index of data to be examined
    :param data_array: data array (must be 2 dimensional)
    :param title: Title of graph
    :param categories: specific categories that should be graphed. In form [[cat 1, label 1], [cat 2, label 2]]
    :return: None
    """

    # heavily based off of code from https://pythonspot.com/matplotlib-bar-chart/

    means_dom = list()
    means_int = list()

    if categories is None:
        categories = find_unique_values(data_array, index)
        for cat in categories:
            means_dom.append(filtered_average(data_array, 7, [[index, cat]]))
            means_int.append(filtered_average(data_array, 8, [[index, cat]]))
        categories_title = categories
    else:
        for cat in categories:
            means_dom.append(filtered_average(data_array, 7, [[index, cat[0]]]))
            means_int.append(filtered_average(data_array, 8, [[index, cat[0]]]))
        categories_title = list()
        for i in categories:
            categories_title.append(i[1])

    means_final = list()
    for i in range(len(means_dom)):
        means_final.append(means_int[i]/means_dom[i])

    # create plot
    fig, ax = plt.subplots()
    index = np.arange(len(means_dom))
    bar_width = 0.35
    opacity = 0.8

    rects1 = plt.bar(index, means_final, bar_width,
                     alpha=opacity,
                     color='b',
                     label='international revenue / domestic')

    plt.xlabel('')
    plt.ylabel(y_label)
    plt.title(title)
    plt.xticks(index + bar_width, categories_title)
    plt.legend()


def bar_graph_dual(data_array, index, title, categories=None):
    """
    Shows a plot of the passed data, plt.show() must be called after all calls of scatter_plot()
    :param categories: specific categories that should be graphed. In form [[cat 1, label 1], [cat 2, label 2]]
    :param index: index of data to be examined
    :param data_array: data array (must be 2 dimensional)
    :param title: Title of graph
    :return: None
    """

    # heavily based off of code from https://pythonspot.com/matplotlib-bar-chart/

    means_dom = list()
    means_int = list()

    if categories is None:
        categories = find_unique_values(data_array, index)
        for cat in categories:
            means_dom.append(filtered_average(data_array, 7, [[index, cat]]))
            means_int.append(filtered_average(data_array, 8, [[index, cat]]))
        categories_title = categories
    else:
        for cat in categories:
            means_dom.append(filtered_average(data_array, 7, [[index, cat[0]]]))
            means_int.append(filtered_average(data_array, 8, [[index, cat[0]]]))
        categories_title = list()
        for i in categories:
            categories_title.append(i[1])

    # create plot
    fig, ax = plt.subplots()
    index = np.arange(len(means_dom))
    bar_width = 0.35
    opacity = 0.8

    rects1 = plt.bar(index, means_dom, bar_width,
                     alpha=opacity,
                     color='b',
                     label='domestic')

    rects2 = plt.bar(index + bar_width, means_int, bar_width,
                     alpha=opacity,
                     color='g',
                     label='international')

    plt.xlabel('')
    plt.ylabel('revenue')
    plt.title(title)
    plt.xticks(index + bar_width, categories_title)
    plt.legend()


def find_unique_values(data, axis) -> list:
    values = set()
    for i in data[axis]:
        values.add(i)
    return list(values)


def scatter_plot(data_array, index_x, index_y, title, x_title, y_title, compute_best_fit=False):
    """
    Shows a plot of the passed data, plt.show() must be called after all calls of scatter_plot()
    :param data_array: data array (must be 2 dimensional)
    :param index_x: Coordinates for x axis
    :param index_y: Coordinates for Y axis
    :param title: Title of graph
    :param x_title: X axis title
    :param y_title: Y axis title
    :param compute_best_fit: Should a best fit line be computed? (boolean)
    :return: None
    """
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.scatter(data_array[index_x], data_array[index_y])

    if compute_best_fit:
        sorted = list()
        for i in range(data_array.shape[1]):
            if not (math.isnan(data_array[index_x][i]) or math.isnan(data_array[index_y][i])):
                sorted.append([data_array[index_x][i], data_array[index_y][i]])

        # this line comes from Stephen on stack exchange
        # (http://stackoverflow.com/questions/3121979/how-to-sort-list-tuple-of-lists-tuples)
        sorted.sort(key=lambda tup: tup[1])

        x = list()
        y = list()
        for i in sorted:
            x.append(i[0])
            y.append(i[1])

        # the next 3 lines come from DSM on stack exchange
        # (http://stackoverflow.com/questions/6148207/linear-regression-with-matplotlib-numpy)
        fit = np.polyfit(x, y, 1)
        fit_fn = np.poly1d(fit)
        plt.plot(x, y, 'yo', x, fit_fn(x), '--k')

        ax1.set_title(title + '\n ( correlation coefecient = '
                      + str(pearsonr_filtered(data_array[index_x], data_array[index_y])[0])
                      + ', regression slope = ' + str(fit_fn[1]) + ')\n')

    else:
        ax1.set_title(title + ')\n')
    ax1.set_xlabel(x_title)
    ax1.set_ylabel(y_title)


def filtered_average(data, target, constraints):
    """
    Calculates the average of columns in the passed numpy array data which meet some constraint
    :param constraints: columns which must equal some value (in form [[0, 2013], [3, FAIL]], which means
                        column 0 must equal 2013 and column 3 must equal FAIL).
    :param target: column to be averaged
    :param data: data array (must be 2 dimensional)
    :return: average value
    """

    sum = 0.0
    n = 0
    for line in range(data.shape[1]):
        failed = False
        for rule in constraints:
            if data[rule[0], line] != rule[1]:
                failed = True
        if failed is False:
            try:
                sum += float(data[target, line])
                n += 1
            except ValueError as e:
                pass  # data[target, line] probably can't be turned into a float
    try:
        return sum / n
    except ZeroDivisionError:
        raise ZeroDivisionError('no float data fit constraints in filtered_average([data], '
                                + str(target) + ' ' + str(constraints))


def print_correlation_array(data, headers):
    """
    Prints a matrix of the correlations between all different variables
    :param data: data array
    :param headers: array of header values
    :return: None
    """

    # TODO: make header_length changeable without messing up formatting

    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

    # Make copy of headers then make them all the same length
    headers_full = headers
    headers = copy.deepcopy(headers)
    header_length = 9
    for i in range(len(headers)):
        if len(headers[i]) > header_length:
            headers[i] = headers[i][0:header_length]
        while len(headers[i]) < header_length:
            headers[i] += ' '
    max_length = 0
    for i in headers_full:
        if len(i) > max_length:
            max_length = len(i)
    for i in range(len(headers_full)):
        while len(headers_full[i]) < max_length:
            headers_full[i] += ' '

    # first z dimension is z values, second z dimension is p values
    corelation_array = np.zeros([data.shape[0], data.shape[0]], dtype=np.float64)

    for i in range(corelation_array.shape[0]):
        for j in range(corelation_array.shape[1]):
            if j < i:
                corelation_array[i][j] = pearsonr_filtered(data[i], data[j])[0]
            else:
                corelation_array[i][j] = -2.0

    coloring_bound_upper = 0.5
    coloring_bound_lower = 0.3
    for i in range(len(headers_full[0])):
        print(' ', end='')
    print(HEADER + "      " +
          str(headers[0:-1]).replace("', '", ' ').replace("('", '').replace("['", '').replace("']", '') + ENDC)
    for i_num in range(1, len(corelation_array)):
        if i_num < 10:
            print(' ', end='')
        print(HEADER + str(i_num) + ' ' + headers_full[i_num] + ENDC, end='')
        i = corelation_array[i_num]
        for j_num in range(len(i) - 1):
            j = i[j_num]
            if j_num > i_num - 1:
                if j_num > i_num:
                    print('    |     ', end='')
                else:
                    print('    \u25BC     ', end='')  # the escape code is for a triangle pointing down
            elif math.isnan(j):
                print('   nan   ', end=' ')
            elif j >= 0:
                if 1.0 > abs(j) > coloring_bound_upper:
                    print(OKGREEN + '   ' + '%.4f' % j + ENDC, end=' ')
                elif 1.0 > abs(j) > coloring_bound_lower:
                    print(OKBLUE + '   ' + '%.4f' % j + ENDC, end=' ')
                else:
                    print('   ' + '%.4f' % j, end=' ')
            else:
                if 1.0 > abs(j) > coloring_bound_upper:
                    print(OKGREEN + '  ' + '%.4f' % j + ENDC, end=' ')
                elif 1.0 > abs(j) > coloring_bound_lower:
                    print(OKBLUE + '   ' + '%.4f' % j + ENDC, end=' ')
                else:
                    print('  ' + '%.4f' % j, end=' ')
        print('   ' + HEADER + str(i_num) + ' ' + headers_full[i_num] + ENDC)
    print('\n')


def pearsonr_filtered(x, y):
    # remove any nan values from x and y
    x = list(copy.deepcopy(x))
    y = list(copy.deepcopy(y))

    initial_len = len(x)

    # a while loop is used instead of a for loop because the list of x changes during loop execution
    i = 0
    while i < len(x):
        try:
            if math.isnan(float(x[i])) or math.isnan(float(y[i])):
                x.pop(i)
                y.pop(i)
                i -= 1
        except ValueError as e:
            x.pop(i)
            y.pop(i)
            i -= 1
        except TypeError as e:
            x.pop(i)
            y.pop(i)
            i -= 1

        i += 1

    if len(x) < initial_len / 4.0:
        # There was not enough numerical data to do proper analysis on
        return math.nan, math.nan
    return stats.pearsonr(np.array(x).astype(np.float), np.array(y).astype(np.float))

# %% [markdown]
# ## Level 1 Analysis

# %%
    # calculate if movies that pass the bechdel test do worse than movies which don't
    print('movies that passed grossed ', filtered_average(data, 8, [[5, "PASS"]]))
    print('movies that failed grossed ', filtered_average(data, 8, [[5, "FAIL"]]))
# Out:
# movies that passed grossed  167359970.8358396
# movies that failed grossed  222529817.73807105

# %% [markdown]
# ## Level 2 Analysis

# %% [markdown]
# Initially, it would appear that movies which pass the Bechdel test make considerably less revenue than their failing counterparts. We shall investigate further.

# %%
print_correlation_array(data, headers)
# Out:
#                     year      imdb      title     test      clean_tes binary    budget_20 domgross_ intgross_
#  1 imdb             nan        ▼         |         |         |         |         |         |         |        1 imdb
#  2 title            nan       nan        ▼         |         |         |         |         |         |        2 title
#  3 test             nan       nan       nan        ▼         |         |         |         |         |        3 test
#  4 clean_test       nan       nan       nan       nan        ▼         |         |         |         |        4 clean_test
#  5 binary           nan       nan       nan       nan       nan        ▼         |         |         |        5 binary
#  6 budget_2013$     0.0777    nan       nan       nan       nan       nan        ▼         |         |        6 budget_2013$
#  7 domgross_2013$  -0.2864    nan       nan       nan       nan       nan       0.4613     ▼         |        7 domgross_2013$
# ...

# %% [markdown]
# There isn't much to see here. This type of plot shows correlations between all the variables, but all of the different Bechdel test results are categorical. There appears to be a slight negative correlation between the year a movie was made and its revenue though, which would imply that movies as a whole are becoming less profitable. However, the correlation coefficient is only -0.28 which implies very slight correlation and this doesn't aid in answering the question posed.

# %%
bar_graph_dual(data, 3, 'Revenue by Test result', [['ok', 'passed'], ['men', 'talked about men'],
                                                         ['notalk', 'didn\'t talk'], ['nowomen', 'no women present'],
                                                         ['dubious', 'dubious']])
bar_graph_divided(data, 3, 'Returns by Test Result', 'return', [['ok', 'passed'], ['men', 'talked about men'],
                                                     ['notalk', 'didn\'t talk'], ['nowomen', 'no women present'],
                                                     ['dubious', 'dubious']])
bar_graph_dual(data, 3, 'Revenue by Test result on movies with disagreement', [['ok-disagree', 'passed'], ['men-disagree', 'talked about men'],
                                                         ['notalk-disagree', 'didn\'t talk'], ['nowomen-disagree', 'no women present'],
                                                         ['dubious-disagree', 'dubious']])
bar_graph_divided(data, 3, 'Returns by Test Result on movies with disagreement', 'return', [['ok-disagree', 'passed'], ['men-disagree', 'talked about men'],
                                                     ['notalk-disagree', 'didn\'t talk'], ['nowomen-disagree', 'no women present'],
                                                     ['dubious-disagree', 'dubious']])
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# These two graphs show the difference between how well movies that passed and failed the Bechdel test did domestically and internationally. It would appear that international audiences don't vary much from U.S. audiences in terms of preferences for or against strong female characters. Movies where no women were present did slightly better than movies that passed and movies where women only talked about men did slightly worse, but these are very small differences. We can, however, tell that movies typically make twice as much internationally as they do domestically.
#
# It is also worth noting that movies where test results were in dispute were more uniform in terms of returns than movies with clear-cut test results.

# %%
data_returns = np.copy(data)
for i in range(data_returns.shape[1]):
    #overwrite collumn 1 and 9 because they're a little useless
    try:
        data_returns[9, i] = str(float(data_returns[7, i]) / float(data_returns[6, i]))
        data_returns[1, i] = str(float(data_returns[8, i]) / float(data_returns[6, i]))
    except:
        data_returns[9, i] = 'N/A'

print('All time means')
print("average (domestic) return of movies that passed                  : ", filtered_average(data_returns, 9, [[4, 'ok']]))
print("average (domestic) return of movies where women talked about men : ", filtered_average(data_returns, 9, [[4, 'men']]))
print("average (domestic) return of movies where women didn't talk      : ", filtered_average(data_returns, 9, [[4, 'notalk']]))
print("average (domestic) return of movies without women                : ", filtered_average(data_returns, 9, [[4, 'nowomen']]))
print()
print("average (international) return of movies that passed                  : ", filtered_average(data_returns, 1, [[4, 'ok']]))
print("average (international) return of movies where women talked about men : ", filtered_average(data_returns, 1, [[4, 'men']]))
print("average (international) return of movies where women didn't talk      : ", filtered_average(data_returns, 1, [[4, 'notalk']]))
print("average (international) return of movies without women                : ", filtered_average(data_returns, 1, [[4, 'nowomen']]))

print('\nMeans from 2013')
print("average (domestic) return of movies that passed                  : ", filtered_average(data_returns, 9, [[4, 'ok'], [0, '2013']]))
print("average (domestic) return of movies where women talked about men : ", filtered_average(data_returns, 9, [[4, 'men'], [0, '2013']]))
print("average (domestic) return of movies where women didn't talk      : ", filtered_average(data_returns, 9, [[4, 'notalk'], [0, '2013']]))
print("average (domestic) return of movies without women                : ", filtered_average(data_returns, 9, [[4, 'nowomen'], [0, '2013']]))
print()
print("average (international) return of movies that passed                  : ", filtered_average(data_returns, 1, [[4, 'ok'], [0, '2013']]))
print("average (international) return of movies where women talked about men : ", filtered_average(data_returns, 1, [[4, 'men'], [0, '2013']]))
print("average (international) return of movies where women didn't talk      : ", filtered_average(data_returns, 1, [[4, 'notalk'], [0, '2013']]))
print("average (international) return of movies without women                : ", filtered_average(data_returns, 1, [[4, 'nowomen'], [0, '2013']]))

headers_edited = copy.deepcopy(headers)
headers_edited[1] = 'inter_ret'
headers_edited[9] = 'dom_retur'

# replace  ok and ok-disagree with 1, men and men-disagree with .5, notalk notalk-disagree with .5,
# nowomen nowomen-disagree with 0, and ignore dubious-disagree and dbious
for i in range(data_returns.shape[0]):
    for j in range(data_returns.shape[1]):
        if data_returns[i, j] == 'ok' or data_returns[i, j] == 'ok-disagree':
            data_returns[i, j] = 1.0
        elif data_returns[i, j] == 'men' or data_returns[i, j] == 'men-disagree':
            data_returns[i, j] = 0.5
        elif data_returns[i, j] == 'notalk' or data_returns[i, j] == 'notalk-disagree':
            data_returns[i, j] = 0.5
        elif data_returns[i, j] == 'nowomen' or data_returns[i, j] == 'nowomen-disagree':
            data_returns[i, j] = 0.0
print()
print_correlation_array(data_returns, headers_edited)
# Out:
# All time means
# average (domestic) return of movies that passed                  :  2.9821489827459513
# average (domestic) return of movies where women talked about men :  4.878819954849991
# average (domestic) return of movies where women didn't talk      :  4.082343874540423
# average (domestic) return of movies without women                :  4.608279883056961
#
# average (international) return of movies that passed                  :  5.299819040280998
# average (international) return of movies where women talked about men :  7.413949586164667
# average (international) return of movies where women didn't talk      :  6.313036251760494
# average (international) return of movies without women                :  6.601937332325277
#
# Means from 2013
# average (domestic) return of movies that passed                  :  2.054264071183064
# average (domestic) return of movies where women talked about men :  2.348989046967629
# ...

# %% [markdown]
# While there appears to be a difference between a movie's return and Bechdel test status when only looking at averages by categories, but the two statistics have an incredibly low correlation coefficient.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It would appear that out of all the movies in the dataset, the movies which did the best had women who talked about men and movies that included women who didn't talk did the worst. This trend seems to be more pronounced in international returns than domestic returns, but it is present in both. On the other hand, however, the correlation between Bechdel test results and the returns of a movie is incredibly small (both have an absolute value less than 0.05). It also appears that movies with disputed Bechdel test results have less pronounced returns than movies with clear-cut test results.
#
# While only looking at the average returns from movies which passed or failed the Bechdel test and the reason they failed would imply that Hollywood is somewhat correct when they claim that movies which fail the Bechdel test, it is only true for movies where women only talk about men and the difference is relatively small.
#
# An interesting point of further study could be the change in people’s preferences over time. Averages over the entire data set show that movies which failed the Bechdel test did better than movies which passed, in 2013 movies which passed did better than movies which had no women or women who didn't talk to each other. This would imply that viewers in 2013 greatly preferred movies with at least some female characters while viewers in 2000 didn't. I know that Lily was investigating this question, but I haven't seen her results yet.
